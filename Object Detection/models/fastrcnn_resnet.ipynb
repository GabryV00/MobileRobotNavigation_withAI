# %%
import torch
import torch.utils.data as data
from PIL import Image
import os
import os.path
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision import transforms
from pycocotools.coco import COCO

os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py")
import utils
from engine import train_one_epoch, evaluate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class CoCoDataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))

    def __getitem__(self, index):
        # Own coco file
        coco = self.coco
        # Image ID
        img_id = self.ids[index]
        # List: get annotation id from coco
        ann_ids = coco.getAnnIds(imgIds=img_id)
        # Dictionary: target coco_annotation file for an image
        coco_annotation = coco.loadAnns(ann_ids)
        # path for input image
        path = coco.loadImgs(img_id)[0]['file_name']
        # open the input image
        img = Image.open(os.path.join(self.root, path))

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # Labels (In my case, I only one class: target class or background)
        labels = torch.ones((num_objs,), dtype=torch.int64)
        # Tensorise img_id
        img_id = torch.tensor([img_id])
        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)
        # Iscrowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        my_annotation = {}
        my_annotation["boxes"] = boxes
        my_annotation["labels"] = labels
        my_annotation["image_id"] = self.ids[index]
        my_annotation["area"] = areas
        my_annotation["iscrowd"] = iscrowd

        if self.transforms is not None:
            img = self.transforms(img)

        return img, my_annotation

    def __len__(self):
        return len(self.ids)

# Since inputs for a PyTorch model must be in tensor format.
def get_transform():
    custom_transforms = []
    custom_transforms.append(torchvision.transforms.ToTensor())
    return torchvision.transforms.Compose(custom_transforms)

# %%
train = CoCoDataset("/content/drive/MyDrive/dataset/train/images", "/content/drive/MyDrive/dataset/train/anno.json", transforms=get_transform())
val = CoCoDataset("/content/drive/MyDrive/dataset/val/images", "/content/drive/MyDrive/dataset/val/anno.json", transforms=get_transform())
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")

num_classes = 5  # 4 class (plane, drone, helicopter, bird) + background
# get number of input features for the classifier
in_features = model.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# %%
# collate_fn needs for batch
def collate_fn(batch):
    return tuple(zip(*batch))

# define training and validation data loaders
data_loader = data.DataLoader(
    train,
    batch_size=1,
    shuffle=True,
    num_workers=2,
    collate_fn=collate_fn
)

data_loader_test = data.DataLoader(
    val,
    batch_size=1,
    shuffle=False,
    num_workers=2,
    collate_fn=collate_fn
)

# %%
# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it for 5 epochs
num_epochs = 15

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/57]  eta: 0:00:20  lr: 0.000094  loss: 0.0435 (0.0435)  loss_classifier: 0.0137 (0.0137)  loss_box_reg: 0.0286 (0.0286)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 0.3583  data: 0.0842  max mem: 1449
# Epoch: [0]  [10/57]  eta: 0:00:10  lr: 0.000986  loss: 0.0433 (0.0459)  loss_classifier: 0.0127 (0.0129)  loss_box_reg: 0.0275 (0.0310)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0011 (0.0014)  time: 0.2129  data: 0.0110  max mem: 1449
# Epoch: [0]  [20/57]  eta: 0:00:07  lr: 0.001878  loss: 0.0379 (0.0420)  loss_classifier: 0.0127 (0.0134)  loss_box_reg: 0.0225 (0.0267)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0011 (0.0014)  time: 0.1985  data: 0.0035  max mem: 1449
# Epoch: [0]  [30/57]  eta: 0:00:05  lr: 0.002770  loss: 0.0387 (0.0474)  loss_classifier: 0.0139 (0.0150)  loss_box_reg: 0.0225 (0.0302)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0009 (0.0013)  time: 0.1988  data: 0.0033  max mem: 1449
# Epoch: [0]  [40/57]  eta: 0:00:03  lr: 0.003662  loss: 0.0413 (0.0454)  loss_classifier: 0.0139 (0.0145)  loss_box_reg: 0.0240 (0.0288)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0010 (0.0014)  time: 0.1995  data: 0.0036  max mem: 1449
# Epoch: [0]  [50/57]  eta: 0:00:01  lr: 0.004554  loss: 0.0457 (0.0486)  loss_classifier: 0.0153 (0.0158)  loss_box_reg: 0.0263 (0.0307)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0011 (0.0014)  time: 0.2014  data: 0.0042  max mem: 1450
# Epoch: [0]  [56/57]  eta: 0:00:00  lr: 0.005000  loss: 0.0499 (0.0492)  loss_classifier: 0.0139 (0.0155)  loss_box_reg: 0.0393 (0.0316)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0011 (0.0015)  time: 0.2025  data: 0.0042  max mem: 1450
# Epoch: [0] Total time: 0:00:11 (0.2042 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0817 (0.0817)  evaluator_time: 0.0014 (0.0014)  time: 0.1678  data: 0.0839  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0858 (0.0859)  evaluator_time: 0.0008 (0.0008)  time: 0.0940  data: 0.0068  max mem: 1450
# Test: Total time: 0:00:01 (0.0969 s / it)
# Averaged stats: model_time: 0.0858 (0.0859)  evaluator_time: 0.0008 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.630
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.670
# Epoch: [1]  [ 0/57]  eta: 0:00:15  lr: 0.005000  loss: 0.0234 (0.0234)  loss_classifier: 0.0058 (0.0058)  loss_box_reg: 0.0155 (0.0155)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0009 (0.0009)  time: 0.2799  data: 0.0798  max mem: 1450
# Epoch: [1]  [10/57]  eta: 0:00:09  lr: 0.005000  loss: 0.0507 (0.0489)  loss_classifier: 0.0152 (0.0156)  loss_box_reg: 0.0310 (0.0316)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 0.2077  data: 0.0100  max mem: 1450
# Epoch: [1]  [20/57]  eta: 0:00:07  lr: 0.005000  loss: 0.0462 (0.0504)  loss_classifier: 0.0152 (0.0150)  loss_box_reg: 0.0310 (0.0336)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0011 (0.0014)  time: 0.2012  data: 0.0034  max mem: 1450
# Epoch: [1]  [30/57]  eta: 0:00:05  lr: 0.005000  loss: 0.0461 (0.0498)  loss_classifier: 0.0114 (0.0141)  loss_box_reg: 0.0315 (0.0336)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0008 (0.0016)  time: 0.2026  data: 0.0035  max mem: 1450
# Epoch: [1]  [40/57]  eta: 0:00:03  lr: 0.005000  loss: 0.0457 (0.0516)  loss_classifier: 0.0126 (0.0143)  loss_box_reg: 0.0315 (0.0352)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0010 (0.0017)  time: 0.2033  data: 0.0036  max mem: 1450
# Epoch: [1]  [50/57]  eta: 0:00:01  lr: 0.005000  loss: 0.0436 (0.0505)  loss_classifier: 0.0127 (0.0141)  loss_box_reg: 0.0301 (0.0343)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0013 (0.0017)  time: 0.2065  data: 0.0056  max mem: 1450
# Epoch: [1]  [56/57]  eta: 0:00:00  lr: 0.005000  loss: 0.0375 (0.0495)  loss_classifier: 0.0116 (0.0139)  loss_box_reg: 0.0252 (0.0335)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0015 (0.0017)  time: 0.2077  data: 0.0059  max mem: 1450
# Epoch: [1] Total time: 0:00:11 (0.2065 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0828 (0.0828)  evaluator_time: 0.0014 (0.0014)  time: 0.1706  data: 0.0857  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0870 (0.0873)  evaluator_time: 0.0008 (0.0009)  time: 0.0956  data: 0.0069  max mem: 1450
# Test: Total time: 0:00:01 (0.0985 s / it)
# Averaged stats: model_time: 0.0870 (0.0873)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.655
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.767
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.695
# Epoch: [2]  [ 0/57]  eta: 0:00:16  lr: 0.005000  loss: 0.0362 (0.0362)  loss_classifier: 0.0112 (0.0112)  loss_box_reg: 0.0222 (0.0222)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.2958  data: 0.0933  max mem: 1450
# Epoch: [2]  [10/57]  eta: 0:00:09  lr: 0.005000  loss: 0.0451 (0.0463)  loss_classifier: 0.0157 (0.0142)  loss_box_reg: 0.0292 (0.0301)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0013 (0.0015)  time: 0.2124  data: 0.0114  max mem: 1450
# Epoch: [2]  [20/57]  eta: 0:00:07  lr: 0.005000  loss: 0.0472 (0.0482)  loss_classifier: 0.0124 (0.0137)  loss_box_reg: 0.0320 (0.0324)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0011 (0.0015)  time: 0.2049  data: 0.0033  max mem: 1450
# Epoch: [2]  [30/57]  eta: 0:00:05  lr: 0.005000  loss: 0.0474 (0.0477)  loss_classifier: 0.0121 (0.0140)  loss_box_reg: 0.0288 (0.0314)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0014 (0.0016)  time: 0.2048  data: 0.0033  max mem: 1450
# Epoch: [2]  [40/57]  eta: 0:00:03  lr: 0.005000  loss: 0.0456 (0.0540)  loss_classifier: 0.0129 (0.0151)  loss_box_reg: 0.0276 (0.0367)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 0.2049  data: 0.0036  max mem: 1450
# Epoch: [2]  [50/57]  eta: 0:00:01  lr: 0.005000  loss: 0.0456 (0.0523)  loss_classifier: 0.0119 (0.0148)  loss_box_reg: 0.0293 (0.0352)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0012 (0.0016)  time: 0.2080  data: 0.0063  max mem: 1450
# Epoch: [2]  [56/57]  eta: 0:00:00  lr: 0.005000  loss: 0.0465 (0.0525)  loss_classifier: 0.0119 (0.0151)  loss_box_reg: 0.0294 (0.0352)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0013 (0.0016)  time: 0.2089  data: 0.0069  max mem: 1450
# Epoch: [2] Total time: 0:00:11 (0.2088 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0871 (0.0871)  evaluator_time: 0.0014 (0.0014)  time: 0.1748  data: 0.0854  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0874 (0.0877)  evaluator_time: 0.0008 (0.0008)  time: 0.0960  data: 0.0069  max mem: 1450
# Test: Total time: 0:00:01 (0.0989 s / it)
# Averaged stats: model_time: 0.0874 (0.0877)  evaluator_time: 0.0008 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.680
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.730
# Epoch: [3]  [ 0/57]  eta: 0:00:16  lr: 0.000500  loss: 0.0262 (0.0262)  loss_classifier: 0.0073 (0.0073)  loss_box_reg: 0.0157 (0.0157)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 0.2899  data: 0.0884  max mem: 1450
# Epoch: [3]  [10/57]  eta: 0:00:09  lr: 0.000500  loss: 0.0325 (0.0336)  loss_classifier: 0.0094 (0.0112)  loss_box_reg: 0.0177 (0.0201)  loss_objectness: 0.0001 (0.0013)  loss_rpn_box_reg: 0.0009 (0.0011)  time: 0.2104  data: 0.0109  max mem: 1450
# Epoch: [3]  [20/57]  eta: 0:00:07  lr: 0.000500  loss: 0.0295 (0.0323)  loss_classifier: 0.0091 (0.0111)  loss_box_reg: 0.0177 (0.0192)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0008 (0.0012)  time: 0.2024  data: 0.0033  max mem: 1450
# Epoch: [3]  [30/57]  eta: 0:00:05  lr: 0.000500  loss: 0.0325 (0.0338)  loss_classifier: 0.0096 (0.0116)  loss_box_reg: 0.0214 (0.0204)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0012)  time: 0.2022  data: 0.0033  max mem: 1450
# Epoch: [3]  [40/57]  eta: 0:00:03  lr: 0.000500  loss: 0.0366 (0.0361)  loss_classifier: 0.0113 (0.0122)  loss_box_reg: 0.0217 (0.0219)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0013)  time: 0.2032  data: 0.0041  max mem: 1450
# Epoch: [3]  [50/57]  eta: 0:00:01  lr: 0.000500  loss: 0.0335 (0.0363)  loss_classifier: 0.0081 (0.0120)  loss_box_reg: 0.0193 (0.0224)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0009 (0.0013)  time: 0.2053  data: 0.0061  max mem: 1450
# Epoch: [3]  [56/57]  eta: 0:00:00  lr: 0.000500  loss: 0.0281 (0.0356)  loss_classifier: 0.0081 (0.0117)  loss_box_reg: 0.0193 (0.0220)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0010 (0.0012)  time: 0.2055  data: 0.0066  max mem: 1450
# Epoch: [3] Total time: 0:00:11 (0.2062 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0890 (0.0890)  evaluator_time: 0.0013 (0.0013)  time: 0.1694  data: 0.0779  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0864 (0.0864)  evaluator_time: 0.0008 (0.0008)  time: 0.0944  data: 0.0066  max mem: 1450
# Test: Total time: 0:00:01 (0.0978 s / it)
# Averaged stats: model_time: 0.0864 (0.0864)  evaluator_time: 0.0008 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.695
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.799
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.745
# Epoch: [4]  [ 0/57]  eta: 0:00:16  lr: 0.000500  loss: 0.0145 (0.0145)  loss_classifier: 0.0027 (0.0027)  loss_box_reg: 0.0092 (0.0092)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0022 (0.0022)  time: 0.2815  data: 0.0839  max mem: 1450
# Epoch: [4]  [10/57]  eta: 0:00:09  lr: 0.000500  loss: 0.0277 (0.0284)  loss_classifier: 0.0079 (0.0097)  loss_box_reg: 0.0166 (0.0167)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0009 (0.0013)  time: 0.2092  data: 0.0107  max mem: 1450
# Epoch: [4]  [20/57]  eta: 0:00:07  lr: 0.000500  loss: 0.0268 (0.0289)  loss_classifier: 0.0096 (0.0103)  loss_box_reg: 0.0166 (0.0168)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0012)  time: 0.2020  data: 0.0035  max mem: 1450
# Epoch: [4]  [30/57]  eta: 0:00:05  lr: 0.000500  loss: 0.0272 (0.0297)  loss_classifier: 0.0096 (0.0106)  loss_box_reg: 0.0167 (0.0174)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.2013  data: 0.0036  max mem: 1450
# Epoch: [4]  [40/57]  eta: 0:00:03  lr: 0.000500  loss: 0.0272 (0.0300)  loss_classifier: 0.0103 (0.0107)  loss_box_reg: 0.0158 (0.0177)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0010)  time: 0.2020  data: 0.0050  max mem: 1450
# Epoch: [4]  [50/57]  eta: 0:00:01  lr: 0.000500  loss: 0.0273 (0.0302)  loss_classifier: 0.0111 (0.0109)  loss_box_reg: 0.0142 (0.0176)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.2049  data: 0.0079  max mem: 1450
# Epoch: [4]  [56/57]  eta: 0:00:00  lr: 0.000500  loss: 0.0273 (0.0300)  loss_classifier: 0.0112 (0.0109)  loss_box_reg: 0.0142 (0.0173)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.2046  data: 0.0078  max mem: 1450
# Epoch: [4] Total time: 0:00:11 (0.2052 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0886 (0.0886)  evaluator_time: 0.0014 (0.0014)  time: 0.1689  data: 0.0755  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0851 (0.0856)  evaluator_time: 0.0008 (0.0008)  time: 0.0937  data: 0.0066  max mem: 1450
# Test: Total time: 0:00:01 (0.0966 s / it)
# Averaged stats: model_time: 0.0851 (0.0856)  evaluator_time: 0.0008 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.730
# Epoch: [5]  [ 0/57]  eta: 0:00:15  lr: 0.000500  loss: 0.0334 (0.0334)  loss_classifier: 0.0184 (0.0184)  loss_box_reg: 0.0146 (0.0146)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 0.2727  data: 0.0775  max mem: 1450
# Epoch: [5]  [10/57]  eta: 0:00:09  lr: 0.000500  loss: 0.0235 (0.0262)  loss_classifier: 0.0077 (0.0093)  loss_box_reg: 0.0146 (0.0159)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.2074  data: 0.0101  max mem: 1450
# Epoch: [5]  [20/57]  eta: 0:00:07  lr: 0.000500  loss: 0.0270 (0.0290)  loss_classifier: 0.0086 (0.0107)  loss_box_reg: 0.0150 (0.0171)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2000  data: 0.0033  max mem: 1450
# Epoch: [5]  [30/57]  eta: 0:00:05  lr: 0.000500  loss: 0.0270 (0.0274)  loss_classifier: 0.0095 (0.0101)  loss_box_reg: 0.0143 (0.0159)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.1987  data: 0.0030  max mem: 1450
# Epoch: [5]  [40/57]  eta: 0:00:03  lr: 0.000500  loss: 0.0261 (0.0282)  loss_classifier: 0.0094 (0.0107)  loss_box_reg: 0.0131 (0.0161)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.2005  data: 0.0040  max mem: 1450
# Epoch: [5]  [50/57]  eta: 0:00:01  lr: 0.000500  loss: 0.0232 (0.0272)  loss_classifier: 0.0094 (0.0101)  loss_box_reg: 0.0141 (0.0157)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.2036  data: 0.0066  max mem: 1450
# Epoch: [5]  [56/57]  eta: 0:00:00  lr: 0.000500  loss: 0.0218 (0.0272)  loss_classifier: 0.0077 (0.0101)  loss_box_reg: 0.0138 (0.0157)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.2032  data: 0.0066  max mem: 1450
# Epoch: [5] Total time: 0:00:11 (0.2035 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0840 (0.0840)  evaluator_time: 0.0014 (0.0014)  time: 0.1693  data: 0.0829  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0849 (0.0854)  evaluator_time: 0.0008 (0.0009)  time: 0.0942  data: 0.0074  max mem: 1450
# Test: Total time: 0:00:01 (0.0973 s / it)
# Averaged stats: model_time: 0.0849 (0.0854)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.683
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.683
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.730
# Epoch: [6]  [ 0/57]  eta: 0:00:16  lr: 0.000050  loss: 0.0136 (0.0136)  loss_classifier: 0.0052 (0.0052)  loss_box_reg: 0.0075 (0.0075)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.2838  data: 0.0873  max mem: 1450
# Epoch: [6]  [10/57]  eta: 0:00:09  lr: 0.000050  loss: 0.0236 (0.0235)  loss_classifier: 0.0106 (0.0100)  loss_box_reg: 0.0112 (0.0123)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.2078  data: 0.0107  max mem: 1450
# Epoch: [6]  [20/57]  eta: 0:00:07  lr: 0.000050  loss: 0.0217 (0.0230)  loss_classifier: 0.0084 (0.0096)  loss_box_reg: 0.0122 (0.0123)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.1993  data: 0.0030  max mem: 1450
# Epoch: [6]  [30/57]  eta: 0:00:05  lr: 0.000050  loss: 0.0248 (0.0265)  loss_classifier: 0.0085 (0.0108)  loss_box_reg: 0.0144 (0.0146)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.1994  data: 0.0031  max mem: 1450
# Epoch: [6]  [40/57]  eta: 0:00:03  lr: 0.000050  loss: 0.0235 (0.0248)  loss_classifier: 0.0090 (0.0100)  loss_box_reg: 0.0121 (0.0137)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2018  data: 0.0044  max mem: 1450
# Epoch: [6]  [50/57]  eta: 0:00:01  lr: 0.000050  loss: 0.0192 (0.0238)  loss_classifier: 0.0071 (0.0095)  loss_box_reg: 0.0112 (0.0133)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2043  data: 0.0068  max mem: 1450
# Epoch: [6]  [56/57]  eta: 0:00:00  lr: 0.000050  loss: 0.0198 (0.0238)  loss_classifier: 0.0072 (0.0095)  loss_box_reg: 0.0117 (0.0133)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2040  data: 0.0067  max mem: 1450
# Epoch: [6] Total time: 0:00:11 (0.2043 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0835 (0.0835)  evaluator_time: 0.0015 (0.0015)  time: 0.1781  data: 0.0920  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0858 (0.0861)  evaluator_time: 0.0008 (0.0009)  time: 0.0947  data: 0.0072  max mem: 1450
# Test: Total time: 0:00:01 (0.0976 s / it)
# Averaged stats: model_time: 0.0858 (0.0861)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [7]  [ 0/57]  eta: 0:00:16  lr: 0.000050  loss: 0.0227 (0.0227)  loss_classifier: 0.0127 (0.0127)  loss_box_reg: 0.0070 (0.0070)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 0.2882  data: 0.0897  max mem: 1450
# Epoch: [7]  [10/57]  eta: 0:00:09  lr: 0.000050  loss: 0.0230 (0.0249)  loss_classifier: 0.0099 (0.0100)  loss_box_reg: 0.0124 (0.0137)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.2087  data: 0.0114  max mem: 1450
# Epoch: [7]  [20/57]  eta: 0:00:07  lr: 0.000050  loss: 0.0203 (0.0233)  loss_classifier: 0.0082 (0.0097)  loss_box_reg: 0.0111 (0.0124)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.2011  data: 0.0036  max mem: 1450
# Epoch: [7]  [30/57]  eta: 0:00:05  lr: 0.000050  loss: 0.0224 (0.0232)  loss_classifier: 0.0082 (0.0098)  loss_box_reg: 0.0101 (0.0123)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.2016  data: 0.0037  max mem: 1450
# Epoch: [7]  [40/57]  eta: 0:00:03  lr: 0.000050  loss: 0.0228 (0.0233)  loss_classifier: 0.0083 (0.0099)  loss_box_reg: 0.0110 (0.0124)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2020  data: 0.0039  max mem: 1450
# Epoch: [7]  [50/57]  eta: 0:00:01  lr: 0.000050  loss: 0.0202 (0.0236)  loss_classifier: 0.0079 (0.0097)  loss_box_reg: 0.0115 (0.0129)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2029  data: 0.0038  max mem: 1450
# Epoch: [7]  [56/57]  eta: 0:00:00  lr: 0.000050  loss: 0.0202 (0.0240)  loss_classifier: 0.0083 (0.0100)  loss_box_reg: 0.0123 (0.0130)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2026  data: 0.0037  max mem: 1450
# Epoch: [7] Total time: 0:00:11 (0.2046 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0821 (0.0821)  evaluator_time: 0.0014 (0.0014)  time: 0.1679  data: 0.0837  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0863 (0.0864)  evaluator_time: 0.0007 (0.0008)  time: 0.0945  data: 0.0068  max mem: 1450
# Test: Total time: 0:00:01 (0.0973 s / it)
# Averaged stats: model_time: 0.0863 (0.0864)  evaluator_time: 0.0007 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [8]  [ 0/57]  eta: 0:00:16  lr: 0.000050  loss: 0.0114 (0.0114)  loss_classifier: 0.0020 (0.0020)  loss_box_reg: 0.0074 (0.0074)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.2829  data: 0.0824  max mem: 1450
# Epoch: [8]  [10/57]  eta: 0:00:09  lr: 0.000050  loss: 0.0214 (0.0228)  loss_classifier: 0.0095 (0.0098)  loss_box_reg: 0.0102 (0.0108)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0004 (0.0009)  time: 0.2087  data: 0.0106  max mem: 1450
# Epoch: [8]  [20/57]  eta: 0:00:07  lr: 0.000050  loss: 0.0214 (0.0230)  loss_classifier: 0.0098 (0.0100)  loss_box_reg: 0.0092 (0.0115)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.2017  data: 0.0033  max mem: 1450
# Epoch: [8]  [30/57]  eta: 0:00:05  lr: 0.000050  loss: 0.0216 (0.0232)  loss_classifier: 0.0082 (0.0096)  loss_box_reg: 0.0112 (0.0123)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2023  data: 0.0032  max mem: 1450
# Epoch: [8]  [40/57]  eta: 0:00:03  lr: 0.000050  loss: 0.0223 (0.0236)  loss_classifier: 0.0082 (0.0095)  loss_box_reg: 0.0129 (0.0128)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2037  data: 0.0047  max mem: 1450
# Epoch: [8]  [50/57]  eta: 0:00:01  lr: 0.000050  loss: 0.0221 (0.0239)  loss_classifier: 0.0092 (0.0096)  loss_box_reg: 0.0119 (0.0129)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.2061  data: 0.0069  max mem: 1450
# Epoch: [8]  [56/57]  eta: 0:00:00  lr: 0.000050  loss: 0.0239 (0.0240)  loss_classifier: 0.0102 (0.0098)  loss_box_reg: 0.0119 (0.0129)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2059  data: 0.0064  max mem: 1450
# Epoch: [8] Total time: 0:00:11 (0.2061 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0879 (0.0879)  evaluator_time: 0.0014 (0.0014)  time: 0.1716  data: 0.0814  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0858 (0.0864)  evaluator_time: 0.0007 (0.0008)  time: 0.0945  data: 0.0067  max mem: 1450
# Test: Total time: 0:00:01 (0.0975 s / it)
# Averaged stats: model_time: 0.0858 (0.0864)  evaluator_time: 0.0007 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [9]  [ 0/57]  eta: 0:00:15  lr: 0.000005  loss: 0.0161 (0.0161)  loss_classifier: 0.0087 (0.0087)  loss_box_reg: 0.0063 (0.0063)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 0.2739  data: 0.0792  max mem: 1450
# Epoch: [9]  [10/57]  eta: 0:00:09  lr: 0.000005  loss: 0.0215 (0.0232)  loss_classifier: 0.0104 (0.0107)  loss_box_reg: 0.0094 (0.0114)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.2088  data: 0.0101  max mem: 1450
# Epoch: [9]  [20/57]  eta: 0:00:07  lr: 0.000005  loss: 0.0215 (0.0227)  loss_classifier: 0.0104 (0.0102)  loss_box_reg: 0.0105 (0.0115)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.2024  data: 0.0031  max mem: 1450
# Epoch: [9]  [30/57]  eta: 0:00:05  lr: 0.000005  loss: 0.0225 (0.0243)  loss_classifier: 0.0093 (0.0101)  loss_box_reg: 0.0117 (0.0132)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.2027  data: 0.0032  max mem: 1450
# Epoch: [9]  [40/57]  eta: 0:00:03  lr: 0.000005  loss: 0.0220 (0.0232)  loss_classifier: 0.0069 (0.0096)  loss_box_reg: 0.0111 (0.0126)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2042  data: 0.0055  max mem: 1450
# Epoch: [9]  [50/57]  eta: 0:00:01  lr: 0.000005  loss: 0.0200 (0.0232)  loss_classifier: 0.0075 (0.0097)  loss_box_reg: 0.0109 (0.0126)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2049  data: 0.0065  max mem: 1450
# Epoch: [9]  [56/57]  eta: 0:00:00  lr: 0.000005  loss: 0.0209 (0.0234)  loss_classifier: 0.0081 (0.0097)  loss_box_reg: 0.0123 (0.0127)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2039  data: 0.0055  max mem: 1450
# Epoch: [9] Total time: 0:00:11 (0.2058 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0862 (0.0862)  evaluator_time: 0.0018 (0.0018)  time: 0.1678  data: 0.0789  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0860 (0.0861)  evaluator_time: 0.0007 (0.0008)  time: 0.0942  data: 0.0066  max mem: 1450
# Test: Total time: 0:00:01 (0.0971 s / it)
# Averaged stats: model_time: 0.0860 (0.0861)  evaluator_time: 0.0007 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [10]  [ 0/57]  eta: 0:00:16  lr: 0.000005  loss: 0.0225 (0.0225)  loss_classifier: 0.0075 (0.0075)  loss_box_reg: 0.0143 (0.0143)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 0.2906  data: 0.0929  max mem: 1450
# Epoch: [10]  [10/57]  eta: 0:00:09  lr: 0.000005  loss: 0.0238 (0.0240)  loss_classifier: 0.0098 (0.0104)  loss_box_reg: 0.0110 (0.0122)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2095  data: 0.0118  max mem: 1450
# Epoch: [10]  [20/57]  eta: 0:00:07  lr: 0.000005  loss: 0.0207 (0.0227)  loss_classifier: 0.0094 (0.0094)  loss_box_reg: 0.0105 (0.0119)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2021  data: 0.0037  max mem: 1450
# Epoch: [10]  [30/57]  eta: 0:00:05  lr: 0.000005  loss: 0.0212 (0.0225)  loss_classifier: 0.0094 (0.0099)  loss_box_reg: 0.0104 (0.0113)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.2026  data: 0.0038  max mem: 1450
# Epoch: [10]  [40/57]  eta: 0:00:03  lr: 0.000005  loss: 0.0230 (0.0239)  loss_classifier: 0.0109 (0.0101)  loss_box_reg: 0.0111 (0.0125)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.2031  data: 0.0049  max mem: 1450
# Epoch: [10]  [50/57]  eta: 0:00:01  lr: 0.000005  loss: 0.0221 (0.0237)  loss_classifier: 0.0098 (0.0100)  loss_box_reg: 0.0121 (0.0124)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2037  data: 0.0058  max mem: 1450
# Epoch: [10]  [56/57]  eta: 0:00:00  lr: 0.000005  loss: 0.0222 (0.0241)  loss_classifier: 0.0098 (0.0103)  loss_box_reg: 0.0121 (0.0127)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2024  data: 0.0052  max mem: 1450
# Epoch: [10] Total time: 0:00:11 (0.2052 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0848 (0.0848)  evaluator_time: 0.0014 (0.0014)  time: 0.1700  data: 0.0828  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0861 (0.0861)  evaluator_time: 0.0008 (0.0009)  time: 0.0944  data: 0.0069  max mem: 1450
# Test: Total time: 0:00:01 (0.0974 s / it)
# Averaged stats: model_time: 0.0861 (0.0861)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [11]  [ 0/57]  eta: 0:00:16  lr: 0.000005  loss: 0.0340 (0.0340)  loss_classifier: 0.0183 (0.0183)  loss_box_reg: 0.0147 (0.0147)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.2856  data: 0.0852  max mem: 1450
# Epoch: [11]  [10/57]  eta: 0:00:09  lr: 0.000005  loss: 0.0217 (0.0216)  loss_classifier: 0.0096 (0.0096)  loss_box_reg: 0.0108 (0.0113)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 0.2086  data: 0.0106  max mem: 1450
# Epoch: [11]  [20/57]  eta: 0:00:07  lr: 0.000005  loss: 0.0197 (0.0219)  loss_classifier: 0.0078 (0.0095)  loss_box_reg: 0.0104 (0.0112)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.2015  data: 0.0033  max mem: 1450
# Epoch: [11]  [30/57]  eta: 0:00:05  lr: 0.000005  loss: 0.0195 (0.0217)  loss_classifier: 0.0079 (0.0094)  loss_box_reg: 0.0104 (0.0112)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.2015  data: 0.0035  max mem: 1450
# Epoch: [11]  [40/57]  eta: 0:00:03  lr: 0.000005  loss: 0.0213 (0.0223)  loss_classifier: 0.0089 (0.0097)  loss_box_reg: 0.0110 (0.0115)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2038  data: 0.0055  max mem: 1450
# Epoch: [11]  [50/57]  eta: 0:00:01  lr: 0.000005  loss: 0.0220 (0.0236)  loss_classifier: 0.0109 (0.0103)  loss_box_reg: 0.0113 (0.0124)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2057  data: 0.0072  max mem: 1450
# Epoch: [11]  [56/57]  eta: 0:00:00  lr: 0.000005  loss: 0.0232 (0.0238)  loss_classifier: 0.0096 (0.0102)  loss_box_reg: 0.0125 (0.0126)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2040  data: 0.0061  max mem: 1450
# Epoch: [11] Total time: 0:00:11 (0.2056 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0859 (0.0859)  evaluator_time: 0.0015 (0.0015)  time: 0.1836  data: 0.0952  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0859 (0.0860)  evaluator_time: 0.0008 (0.0009)  time: 0.0951  data: 0.0077  max mem: 1450
# Test: Total time: 0:00:01 (0.0980 s / it)
# Averaged stats: model_time: 0.0859 (0.0860)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [12]  [ 0/57]  eta: 0:00:16  lr: 0.000001  loss: 0.0281 (0.0281)  loss_classifier: 0.0100 (0.0100)  loss_box_reg: 0.0169 (0.0169)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 0.2885  data: 0.0896  max mem: 1450
# Epoch: [12]  [10/57]  eta: 0:00:09  lr: 0.000001  loss: 0.0209 (0.0246)  loss_classifier: 0.0089 (0.0092)  loss_box_reg: 0.0117 (0.0133)  loss_objectness: 0.0002 (0.0013)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2090  data: 0.0112  max mem: 1450
# Epoch: [12]  [20/57]  eta: 0:00:07  lr: 0.000001  loss: 0.0205 (0.0245)  loss_classifier: 0.0078 (0.0093)  loss_box_reg: 0.0117 (0.0135)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2011  data: 0.0033  max mem: 1450
# Epoch: [12]  [30/57]  eta: 0:00:05  lr: 0.000001  loss: 0.0202 (0.0240)  loss_classifier: 0.0081 (0.0094)  loss_box_reg: 0.0117 (0.0130)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2017  data: 0.0032  max mem: 1450
# Epoch: [12]  [40/57]  eta: 0:00:03  lr: 0.000001  loss: 0.0208 (0.0236)  loss_classifier: 0.0099 (0.0097)  loss_box_reg: 0.0107 (0.0125)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.2050  data: 0.0062  max mem: 1450
# Epoch: [12]  [50/57]  eta: 0:00:01  lr: 0.000001  loss: 0.0215 (0.0233)  loss_classifier: 0.0101 (0.0096)  loss_box_reg: 0.0107 (0.0123)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.2065  data: 0.0081  max mem: 1450
# Epoch: [12]  [56/57]  eta: 0:00:00  lr: 0.000001  loss: 0.0224 (0.0236)  loss_classifier: 0.0105 (0.0097)  loss_box_reg: 0.0110 (0.0126)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2048  data: 0.0064  max mem: 1450
# Epoch: [12] Total time: 0:00:11 (0.2060 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0851 (0.0851)  evaluator_time: 0.0015 (0.0015)  time: 0.1739  data: 0.0863  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0861 (0.0863)  evaluator_time: 0.0008 (0.0009)  time: 0.0948  data: 0.0071  max mem: 1450
# Test: Total time: 0:00:01 (0.0977 s / it)
# Averaged stats: model_time: 0.0861 (0.0863)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [13]  [ 0/57]  eta: 0:00:16  lr: 0.000001  loss: 0.0174 (0.0174)  loss_classifier: 0.0045 (0.0045)  loss_box_reg: 0.0110 (0.0110)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.2849  data: 0.0868  max mem: 1450
# Epoch: [13]  [10/57]  eta: 0:00:09  lr: 0.000001  loss: 0.0218 (0.0225)  loss_classifier: 0.0099 (0.0101)  loss_box_reg: 0.0104 (0.0109)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.2100  data: 0.0113  max mem: 1450
# Epoch: [13]  [20/57]  eta: 0:00:07  lr: 0.000001  loss: 0.0218 (0.0237)  loss_classifier: 0.0093 (0.0102)  loss_box_reg: 0.0107 (0.0122)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.2022  data: 0.0037  max mem: 1450
# Epoch: [13]  [30/57]  eta: 0:00:05  lr: 0.000001  loss: 0.0235 (0.0245)  loss_classifier: 0.0104 (0.0106)  loss_box_reg: 0.0127 (0.0126)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2015  data: 0.0039  max mem: 1450
# Epoch: [13]  [40/57]  eta: 0:00:03  lr: 0.000001  loss: 0.0241 (0.0240)  loss_classifier: 0.0104 (0.0103)  loss_box_reg: 0.0128 (0.0125)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2034  data: 0.0050  max mem: 1450
# Epoch: [13]  [50/57]  eta: 0:00:01  lr: 0.000001  loss: 0.0222 (0.0241)  loss_classifier: 0.0088 (0.0100)  loss_box_reg: 0.0117 (0.0129)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.2052  data: 0.0056  max mem: 1450
# Epoch: [13]  [56/57]  eta: 0:00:00  lr: 0.000001  loss: 0.0222 (0.0239)  loss_classifier: 0.0091 (0.0101)  loss_box_reg: 0.0111 (0.0126)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2041  data: 0.0048  max mem: 1450
# Epoch: [13] Total time: 0:00:11 (0.2057 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0875 (0.0875)  evaluator_time: 0.0015 (0.0015)  time: 0.1739  data: 0.0838  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0869 (0.0866)  evaluator_time: 0.0008 (0.0009)  time: 0.0950  data: 0.0070  max mem: 1450
# Test: Total time: 0:00:01 (0.0979 s / it)
# Averaged stats: model_time: 0.0869 (0.0866)  evaluator_time: 0.0008 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# Epoch: [14]  [ 0/57]  eta: 0:00:16  lr: 0.000001  loss: 0.0294 (0.0294)  loss_classifier: 0.0111 (0.0111)  loss_box_reg: 0.0171 (0.0171)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 0.2838  data: 0.0876  max mem: 1450
# Epoch: [14]  [10/57]  eta: 0:00:09  lr: 0.000001  loss: 0.0192 (0.0232)  loss_classifier: 0.0083 (0.0089)  loss_box_reg: 0.0110 (0.0133)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0009 (0.0009)  time: 0.2102  data: 0.0109  max mem: 1450
# Epoch: [14]  [20/57]  eta: 0:00:07  lr: 0.000001  loss: 0.0191 (0.0224)  loss_classifier: 0.0083 (0.0088)  loss_box_reg: 0.0110 (0.0127)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2025  data: 0.0033  max mem: 1450
# Epoch: [14]  [30/57]  eta: 0:00:05  lr: 0.000001  loss: 0.0209 (0.0218)  loss_classifier: 0.0068 (0.0086)  loss_box_reg: 0.0107 (0.0122)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.2030  data: 0.0040  max mem: 1450
# Epoch: [14]  [40/57]  eta: 0:00:03  lr: 0.000001  loss: 0.0217 (0.0229)  loss_classifier: 0.0086 (0.0091)  loss_box_reg: 0.0121 (0.0127)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.2051  data: 0.0063  max mem: 1450
# Epoch: [14]  [50/57]  eta: 0:00:01  lr: 0.000001  loss: 0.0208 (0.0224)  loss_classifier: 0.0084 (0.0088)  loss_box_reg: 0.0110 (0.0124)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 0.2054  data: 0.0067  max mem: 1450
# Epoch: [14]  [56/57]  eta: 0:00:00  lr: 0.000001  loss: 0.0221 (0.0231)  loss_classifier: 0.0100 (0.0094)  loss_box_reg: 0.0109 (0.0126)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.2044  data: 0.0054  max mem: 1450
# Epoch: [14] Total time: 0:00:11 (0.2064 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:03  model_time: 0.0838 (0.0838)  evaluator_time: 0.0014 (0.0014)  time: 0.1813  data: 0.0947  max mem: 1450
# Test:  [19/20]  eta: 0:00:00  model_time: 0.0855 (0.0860)  evaluator_time: 0.0008 (0.0008)  time: 0.0948  data: 0.0074  max mem: 1450
# Test: Total time: 0:00:01 (0.0977 s / it)
# Averaged stats: model_time: 0.0855 (0.0860)  evaluator_time: 0.0008 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
